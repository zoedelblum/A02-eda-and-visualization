# %% [markdown]
# # Assignment: Exploratory Data Analysis

# %% [markdown]
# **Q1.** In class, we talked about how to compute the sample mean of a variable $X$,
# $$
# m(X) = \dfrac{1}{N} \sum_{i=1}^N x_i
# $$
# and sample covariance of two variables $X$ and $Y$,
# $$
# \text{cov}(X,Y) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(y_i - m(Y))).
# $$
# Recall, the sample variance of $X$ is
# $$
# s^2 = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2.
# $$
# It can be very helpful to understand some basic properties of these statistics. If you want to write your calculations on a piece of paper, take a photo, and upload that to your GitHub repo, that's probably easiest.
#
# 1. Show that $m(a + bX) = a+b \times m(X)$.
# 2. Show that $\text{cov}(X,a+bY) = b \times \text{cov}(X,Y)$
# 3. Show that $\text{cov}(a+bX,a+bX) = b^2 \text{cov}(X,X) $, and in particular that $\text{cov}(X,X) = s^2 $.
# 4. Consider a non-decreasing transformation $g()$. Is is always true that $m(g(X))= g(m(X))$?

# %% [markdown]
# **Q2.** This question looks at financial transfers from foreign entities to American universities. In particular, from which countries and giftors are the gifts coming from, and to which institutions are they going? For this question, `.groupby([vars]).count()` and `.groupby([vars]).sum()` will be especially useful to tally the number of occurrences and sum the values of those occurrences.
#
# 1. Load the `./data/ForeignGifts_edu.csv` dataset.
# 2. For `Foreign Gift Amount`, create a histogram and describe the variable. Describe your findings.
# 3. For `Gift Type`, create a histogram or value counts table. What proportion of the gifts are contracts, real estate, and monetary gifts?
# 4. Create a kernel density plot of the log of `Foreign Gift Amount`, and then a kernel density plot of the log of `Foreign Gift Amount` conditional on gift type. Do you notice any patterns?
# 5. What are the top 15 countries in terms of the number of gifts? What are the top 15 countries in terms of the amount given?
# 6. Which giftors provide the most money, in total?

# %% [markdown]
# ---

# %% [markdown]
# ## *Phase 1: Solution without AI
#
# Complete all questions in the following cells without generative AI. Then commit and push the
# notebook before beginning Phase 2.

# %% [markdown]
# **Declaration:** I completed this version without generative AI.
#
# **Student(s):** Zoe Edelblum
#
# **Date:** 9/9/26

# %%
# Your Phase 1 solution to the problem goes here.

# %% [markdown]
# **Q1.1**
#
# $m(a + bX) = a+b \times m(X)$
#
# $\dfrac{1}{N} \sum_{i=1}^N a + bx_i = a + b \times \dfrac{1}{N} \sum_{i=1}^N x_i$
#
# $a + \dfrac{1}{N} \sum_{i=1}^N bx_i = a + b \times \dfrac{1}{N} \sum_{i=1}^N x_i$
#
# $a + b \times \dfrac{1}{N} \sum_{i=1}^N x_i = a + b \times \dfrac{1}{N} \sum_{i=1}^N x_i$

# %% [markdown]
# **Q1.2**
#
# $\text{cov}(X,a+bY) = b \times \text{cov}(X,Y)$
#
# $\dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(a+bY_i - m(a+bY))) = b \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(Y_i - m(Y)))$
#
# $\dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(a+bY_i - a+b \times m(Y))) = b \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(Y_i - m(Y)))$
#
# $\dfrac{1}{N} \sum_{i=1}^N (x_i - \dfrac{1}{N} \sum_{i=1}^N x_i)(a+b \times Y_i - a+b \times \dfrac{1}{N} \sum_{i=1}^N (Y)_i)) = b \times \dfrac{1}{N} \sum_{i=1}^N (x_i - \dfrac{1}{N} \sum_{i=1}^N x_i)(Y_i - \dfrac{1}{N} \sum_{i=1}^N Y_i))$
#
# $\dfrac{1}{N} \sum_{i=1}^N (x_i - \dfrac{1}{N} \sum_{i=1}^N x_i)(b \times Y_i - b \times \dfrac{1}{N} \sum_{i=1}^N (Y)_i)) = b \times \dfrac{1}{N} \sum_{i=1}^N (x_i - \dfrac{1}{N} \sum_{i=1}^N x_i)(Y_i - \dfrac{1}{N} \sum_{i=1}^N Y_i))$
#
# $\dfrac{1}{N} \sum_{i=1}^N (x_i - m(x))(b \times Y_i - b \times m(Y))) = b \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(x))(Y_i - m(Y)))$
#
# $b \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(x))(Y_i - m(Y))) = b \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(x))(Y_i - m(Y)))$
#
# $b \times \text{cov}(X,Y) = b \times \text{cov}(X,Y)$

# %% [markdown]
# **Q1.3**
#
# $\text{cov}(a+bX,a+bX) = b^2 \text{cov}(X,X) $
#
# $\dfrac{1}{N} \sum_{i=1}^N (a+bx_i - m(a+bX))(a+bx_i - m(a+bX))) = b^2 \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(x_i - m(X)))$
#
# $\dfrac{1}{N} \sum_{i=1}^N (a+bx_i - a+b \times m(X))(a+bx_i - a+b \times m(X))) = b^2 \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(x_i - m(X)))$
#
# $\dfrac{1}{N} \sum_{i=1}^N (a+b \times x_i - a+b \times \dfrac{1}{N} \sum_{i=1}^N X_i)(a+b \times x_i - a+b \times \dfrac{1}{N} \sum_{i=1}^N (X)_i)) = b^2 \times \dfrac{1}{N} \sum_{i=1}^N (x_i - \dfrac{1}{N} \sum_{i=1}^N X_i)(x_i - \dfrac{1}{N} \sum_{i=1}^N X_i))$
#
# $\dfrac{1}{N} \sum_{i=1}^N (b \times x_i - b \times \dfrac{1}{N} \sum_{i=1}^N X_i)(b \times x_i - b \times \dfrac{1}{N} \sum_{i=1}^N (X)_i)) = b^2 \times \dfrac{1}{N} \sum_{i=1}^N (x_i - \dfrac{1}{N} \sum_{i=1}^N X_i)(x_i - \dfrac{1}{N} \sum_{i=1}^N X_i))$
#
# $\dfrac{1}{N} \sum_{i=1}^N (b \times x_i - b \times m(X))(b \times x_i - b \times m(X))) = b^2 \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(x_i - m(X)))$
#
# $b^2 \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(x_i - m(X))) = b^2 \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(x_i - m(X)))$
#
# $b^2 \times \text{cov}(X,X) = b^2 \times \text{cov}(X,X)$
#
# $\text{cov}(X,X) = s^2$
#
# $\dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(x_i - m(X)) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2$
#
# $\dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2 = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2$

# %% [markdown]
# **Q1.4**
#
# $\dfrac{1}{N} \sum_{i=1}^N g(X)_i = g(\dfrac{1}{N} \sum_{i=1}^N X_i)$
#
# It isn't always true that $m(g(X))=g(m(X))$.
#
# For example, let $X={1,3}$ and $g(X)=X^2$.
#
# $m(X)=\dfrac{1+3}{2}=2$
#
# $g(m(X))=g(2)=2^2=4$
#
# $m(g(X))=\dfrac{1^2+3^2}{2}=\dfrac{1+9}{2}=5$
#
# Therefore, $m(g(X))=5\neq4=g(m(X))$.

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install numpy

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

foreign_gifts = pd.read_csv("data/ForeignGifts_edu.csv")

#2.2
foreign_gifts["Foreign Gift Amount"].describe()
foreign_gifts["Foreign Gift Amount"].hist(bins=50)
plt.xlabel("Foreign Gift Amount")
plt.ylabel("Frequency")
plt.title("Distribution of Foreign Gift Amount")
plt.show()

#2.3
gift_type_counts = foreign_gifts["Gift Type"].value_counts()
gift_type_proportions = foreign_gifts["Gift Type"].value_counts(normalize=True)
print(gift_type_counts)
print(gift_type_proportions[["Contract", "Real Estate", "Monetary Gift"]])
ax = gift_type_counts.plot(kind="bar")
plt.xlabel("Gift Type")
plt.ylabel("Number of Gifts")
plt.title("Number of Gifts by Gift Type")
for i, proportion in enumerate(gift_type_proportions[gift_type_counts.index]):
    ax.text(i, gift_type_counts.iloc[i], f"{proportion:.1%}", ha="center", va="bottom")
plt.show()

#2.4
foreign_gifts_positive = foreign_gifts[foreign_gifts["Foreign Gift Amount"] > 0].copy()
foreign_gifts_positive["Log Gift Amount"] = np.log(foreign_gifts_positive["Foreign Gift Amount"])
sns.kdeplot(data=foreign_gifts_positive, x="Log Gift Amount")
plt.xlabel("Log of Foreign Gift Amount")
plt.title("Density of Log Foreign Gift Amount")
plt.show()
sns.kdeplot(data=foreign_gifts_positive,x="Log Gift Amount",hue="Gift Type")
plt.xlabel("Log of Foreign Gift Amount")
plt.title("Density of Log Foreign Gift Amount by Gift Type")
plt.show()

#2.5
top_15_countries_count = (foreign_gifts.groupby("Country of Giftor").count()["Foreign Gift Amount"].sort_values(ascending=False).head(15))
print(top_15_countries_count)
top_15_countries_amount = (foreign_gifts.groupby("Country of Giftor")["Foreign Gift Amount"].sum().sort_values(ascending=False).head(15))
print(top_15_countries_amount)

#2.6
giftor_summary = (foreign_gifts.groupby("Giftor Name").agg(Number_of_Gifts=("Foreign Gift Amount", "count"), Total_Amount=("Foreign Gift Amount", "sum")).sort_values("Total_Amount", ascending=False))
giftor_summary.head(15)
# Out:
# Gift Type
# Contract         17274
# Monetary Gift    10936
# Real Estate         11
# Name: count, dtype: int64
# Gift Type
# Contract         0.612097
# Real Estate      0.000390
# Monetary Gift    0.387513
# Name: proportion, dtype: float64
# Country of Giftor
# ENGLAND            3655
# CHINA              2461
# CANADA             2344
# JAPAN              1896
# SWITZERLAND        1676
# SAUDI ARABIA       1610
# FRANCE             1437
# GERMANY            1394
# HONG KONG          1080
# SOUTH KOREA         811
# QATAR               693
# THE NETHERLANDS     512
# KOREA               452
# INDIA               434
# TAIWAN              381
# Name: Foreign Gift Amount, dtype: int64
# Country of Giftor
# QATAR                   2706240869
# ENGLAND                 1464906771
# CHINA                   1237952112
# SAUDI ARABIA            1065205930
# BERMUDA                  899593972
# CANADA                   898160656
# HONG KONG                887402529
# ...

# %% [markdown]
# 2.2. The distribution of foreign gift amounts is right-skewed. There are a lot more smaller gifts, and the frequency decreases as the gift amount gets larger. There are also some very large gifts that create the long right tail.
#
# 2.3. The propotions are as follows: contracts is 61.2 %, monetary gift is 38.8%, and real estate is 0.0%.
#
# 2.4. After taking the log of the gift amount, the distribution is much less right-skewed than the original distribution. The values are more concentrated, which makes the overall distribution easier to compare. When we separate the distribution by gift type, we can see that real estate appears to remain at zero and contracts are the highest in density with one major peak.
#
# 2.5. The top 15 countries in terms of the number of gifts are England, Chine, Canada, Japan, Switzerland, Saudi Arabia, Franze, Germany, Hong King, South Korea, Qatar, the Netherlands, Korea, India, and Taiwan. The top 15 countries in terms of the amount given are Qatar, England, China, Saudi Arabia, Bermuda, Canada, Hong Kong, Japan, Switzerland, India, Germany, United Arab Emrites, France, Singapore, and Australia.
#
# 2.6. The Qatar Foundations, Saudi Arabian Cultural Mission, HCL, Church of Jesus Christ of LDS, and Emrites Institue for Advamces Sc are the not anonymous giftors that provide the most money in total.

# %% [markdown]
# ## *Phase 2: AI-assisted Revision
# Keep Phase 1 frozen.

# %% [markdown]
# - **Phase 1 commit SHA ID:** 6857beca633cbb74725b02cab5ed32ae589d6249
# - **AI tool and model used:** Claude Sonnet 5

# %% [markdown]
# ### *Prompts used

# %% [markdown]
# 1. I attached all necessary information about my assignment. Propose any changes that will correct/improve my answer.
# 2. Now, give me a concise numbered list with your proposed changes

# %% [markdown]
# ### *AI-proposed changes

# %% [markdown]
# [Paste the AI's concise numbered list verbatim.]
#
# 1. **Q1.2 & Q1.3 proofs** – Rewrite so you start from one side of the equation (e.g., `cov(X, a+bY) = ...`) and derive the other side, rather than writing the full target equation as your first line and simplifying both sides in parallel (currently reads as circular).
# 2. **Q2.2** – Print/keep the `.describe()** output and reference specific numbers (e.g., mean vs. median) in your write-up, not just the chart.
# 3. **Q2.2** – Add a log-scale histogram, since the current one is unreadable (almost all mass in one bin due to outliers).
# 4. **Q2.2** – Fix typo: "propotions" → "proportions."
# 5. **Q2.3** – No content changes; just confirm proportions are stated in prose (already done correctly).
# 6. **Q2.4** – Correct the real estate interpretation: the flat curve is a KDE artifact from too few observations (n=11), not evidence that gift amounts are near zero.
# 7. **Q2.4** – Add the Contract vs. Monetary Gift pattern: Contract is unimodal (peak ~log 13), Monetary Gift is bimodal (peaks ~log 5 and ~log 13).
# 8. **Q2.5** – Fix typos: "Chine" → China, "Franze" → France, "Hong King" → Hong Kong.
# 9. **Q2.5** (optional/style) – Rewrite the groupby using named aggregation (`.agg(...)`) for consistency with Q2.6, producing both top-15 tables from a single groupby call.
# 10. **Q2.6** – Fix typos: "Emrites" → Emirates, "Institue" → Institute, "Advamces" → Advances (and "United Arab Emrites" in Q2.5).
# 11. **Q2.6** – Explicitly state that "Anonymous" and "Anonymous #9" were excluded because they aren't real giftor identities.
# 12. **Q2.6** – Clarify that "Qatar Foundation," "Qatar Foundation/Qatar National Res," and "Qatar Foundation for Education" are three separate rows in your data (likely the same entity recorded inconsistently) rather than referring to them collectively as one "Qatar Foundations" line item.

# %% [markdown]
# ### *Evaluation of AI suggestions

# %% [markdown]
# | Change | Decision | Reason and verification |
# |---|---|---|
# | 1 | Accept | Can make it cleaner and easier to read |
# | 2 | Accept | Allows better and mroe specific data analysis |
# | 3 | Accept | Will make it easier to read the graph |
# | 4 | Accept | Typo being fixed |
# | 5 | Accept | Validating everything is correct |
# | 6 | Accept | Will imrpove the quality and accuracy of the graph |
# | 7 | Accept | Will improve the analysis/description |
# | 8 | Accept | Typo being fixed |
# | 9 | Accept | Minimizing amount of code |
# | 10 | Accept | Typo being fixed |
# | 11 | Accept | Will improve the analysis/description |
# | 12 | Accept | Will improve the analysis/description |

# %% [markdown]
# ### *AI-assisted solution in full
# After the evaluation of AI suggestions, incorporate the accepted revisions into your Phase 1 solution and provide the final Phase 2 solution in full in the following cells.

# %% [markdown]
# **Q1.1**
#
# $m(a + bX) = a+b \times m(X)$
#
# $\dfrac{1}{N} \sum_{i=1}^N a + bx_i = a + b \times \dfrac{1}{N} \sum_{i=1}^N x_i$
#
# $a + \dfrac{1}{N} \sum_{i=1}^N bx_i = a + b \times \dfrac{1}{N} \sum_{i=1}^N x_i$
#
# $a + b \times \dfrac{1}{N} \sum_{i=1}^N x_i = a + b \times \dfrac{1}{N} \sum_{i=1}^N x_i$

# %% [markdown]
# **Q1.2**
#
# $\text{cov}(X,a+bY) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(a+bY_i - m(a+bY))$
#
# Using the Q1.1 result, $m(a+bY) = a + b \times m(Y)$:
#
# $= \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(a+bY_i - a - b \times m(Y))$
#
# $= \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(bY_i - b \times m(Y))$
#
# $= \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X)) \times b(Y_i - m(Y))$
#
# $= b \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(Y_i - m(Y))$
#
# $= b \times \text{cov}(X,Y)$

# %% [markdown]
# **Q1.3**
#
# $\text{cov}(a+bX,a+bX) = \dfrac{1}{N} \sum_{i=1}^N (a+bx_i - m(a+bX))(a+bx_i - m(a+bX))$
#
# Using $m(a+bX) = a + b \times m(X)$:
#
# $= \dfrac{1}{N} \sum_{i=1}^N (a+bx_i - a - b \times m(X))(a+bx_i - a - b \times m(X))$
#
# $= \dfrac{1}{N} \sum_{i=1}^N (bx_i - b \times m(X))(bx_i - b \times m(X))$
#
# $= \dfrac{1}{N} \sum_{i=1}^N b^2(x_i - m(X))(x_i - m(X))$
#
# $= b^2 \times \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(x_i - m(X))$
#
# $= b^2 \times \text{cov}(X,X)$
#
# In particular, setting $a=0, b=1$:
#
# $\text{cov}(X,X) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(x_i - m(X)) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2 = s^2$

# %% [markdown]
# **Q1.4**
#
# $\dfrac{1}{N} \sum_{i=1}^N g(X)_i = g(\dfrac{1}{N} \sum_{i=1}^N X_i)$
#
# It isn't always true that $m(g(X))=g(m(X))$.
#
# For example, let $X={1,3}$ and $g(X)=X^2$.
#
# $m(X)=\dfrac{1+3}{2}=2$
#
# $g(m(X))=g(2)=2^2=4$
#
# $m(g(X))=\dfrac{1^2+3^2}{2}=\dfrac{1+9}{2}=5$
#
# Therefore, $m(g(X))=5\neq4=g(m(X))$.

# %%
# Your Phase 2 solution to the problem goes here.
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install numpy

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

foreign_gifts = pd.read_csv("data/ForeignGifts_edu.csv")

# %%
#2.2
summary_stats = foreign_gifts["Foreign Gift Amount"].describe()
print(summary_stats)

#Original scale histogram
foreign_gifts["Foreign Gift Amount"].hist(bins=50)
plt.xlabel("Foreign Gift Amount")
plt.ylabel("Frequency")
plt.title("Distribution of Foreign Gift Amount")
plt.show()

#Log-scale histogram to see the shape of the bulk of the distribution
foreign_gifts.loc[foreign_gifts["Foreign Gift Amount"] > 0, "Foreign Gift Amount"] \
    .apply(np.log10).hist(bins=50)
plt.xlabel("log10(Foreign Gift Amount)")
plt.ylabel("Frequency")
plt.title("Distribution of Foreign Gift Amount (log scale)")
plt.show()
# Out:
# count    2.822100e+04
# mean     5.882327e+05
# std      3.222011e+06
# min     -5.377700e+05
# 25%      5.700000e+03
# 50%      9.461500e+04
# 75%      3.761420e+05
# max      1.000000e+08
# Name: Foreign Gift Amount, dtype: float64

# %% [markdown]
# **2.2.** The distribution of foreign gift amounts is strongly right-skewed. The mean ($588,233) is over six times the median ($94,615), which is the classic signature of right skew — a small number of very large gifts pull the mean well above the typical gift. On the original scale, the histogram is dominated by these outliers, with nearly all ~28,000 gifts crammed into the first bin and gift amounts extending out to $100 million. On the log scale, the distribution is roughly unimodal and much more interpretable, peaking around $10^5 - 10^{5.5}$ (i.e., gifts in the $100,000–$300,000 range are most common). One additional detail worth noting: the minimum gift amount is -$537,770, meaning some records have negative values, possibly corrections or adjustments to previously reported gifts, which is worth flagging as a data-quality consideration.

# %%
#2.3
gift_type_counts = foreign_gifts["Gift Type"].value_counts()
gift_type_proportions = foreign_gifts["Gift Type"].value_counts(normalize=True)

print(gift_type_counts)
print(gift_type_proportions[["Contract", "Real Estate", "Monetary Gift"]])

ax = gift_type_counts.plot(kind="bar")
plt.xlabel("Gift Type")
plt.ylabel("Number of Gifts")
plt.title("Number of Gifts by Gift Type")
for i, proportion in enumerate(gift_type_proportions[gift_type_counts.index]):
    ax.text(i, gift_type_counts.iloc[i], f"{proportion:.1%}", ha="center", va="bottom")
plt.show()
# Out:
# Gift Type
# Contract         17274
# Monetary Gift    10936
# Real Estate         11
# Name: count, dtype: int64
# Gift Type
# Contract         0.612097
# Real Estate      0.000390
# Monetary Gift    0.387513
# Name: proportion, dtype: float64

# %% [markdown]
# **2.3.** The proportions are as follows: contracts are 61.2%, monetary gifts are 38.8%, and real estate is 0.04% (11 out of 28,221 gifts).

# %%
#2.4
foreign_gifts_positive = foreign_gifts[foreign_gifts["Foreign Gift Amount"] > 0].copy()
foreign_gifts_positive["Log Gift Amount"] = np.log(foreign_gifts_positive["Foreign Gift Amount"])

sns.kdeplot(data=foreign_gifts_positive, x="Log Gift Amount")
plt.xlabel("Log of Foreign Gift Amount")
plt.title("Density of Log Foreign Gift Amount")
plt.show()

sns.kdeplot(data=foreign_gifts_positive, x="Log Gift Amount", hue="Gift Type")
plt.xlabel("Log of Foreign Gift Amount")
plt.title("Density of Log Foreign Gift Amount by Gift Type")
plt.show()

# %% [markdown]
# **2.4.** After taking the log of the gift amount, the distribution is much less right-skewed than the original — values are more concentrated, making the overall shape easier to interpret and compare. When separated by gift type, Contract gifts are unimodal with a single sharp peak around log ≈ 13, indicating most contracts cluster around a similar (large) dollar value. Monetary Gift is bimodal, with one peak around log ≈ 5 and another around log ≈ 13, suggesting two distinct regimes: many smaller gifts and a separate cluster of very large ones. Real Estate has only 11 observations, too few for a meaningful kernel density estimate, so its curve stays flat near zero rather than reflecting the actual distribution of real estate gift values.

# %%
#2.5
country_summary = (foreign_gifts.groupby("Country of Giftor")
    .agg(Number_of_Gifts=("Foreign Gift Amount", "count"),
         Total_Amount=("Foreign Gift Amount", "sum")))

top_15_countries_count = country_summary.sort_values("Number_of_Gifts", ascending=False).head(15)
top_15_countries_amount = country_summary.sort_values("Total_Amount", ascending=False).head(15)

print(top_15_countries_count)
print(top_15_countries_amount)
# Out:
#                    Number_of_Gifts  Total_Amount
# Country of Giftor
# ENGLAND                       3655    1464906771
# CHINA                         2461    1237952112
# CANADA                        2344     898160656
# JAPAN                         1896     655954776
# SWITZERLAND                   1676     619899445
# SAUDI ARABIA                  1610    1065205930
# FRANCE                        1437     405839396
# GERMANY                       1394     442475605
# HONG KONG                     1080     887402529
# SOUTH KOREA                    811     149238934
# QATAR                          693    2706240869
# THE NETHERLANDS                512     166062836
# KOREA                          452     119415910
# INDIA                          434     539556490
# TAIWAN                         381     110412151
#                       Number_of_Gifts  Total_Amount
# Country of Giftor
# QATAR                             693    2706240869
# ...

# %% [markdown]
# **2.5.** The top 15 countries in terms of number of gifts are England, China, Canada, Japan, Switzerland, Saudi Arabia, France, Germany, Hong Kong, South Korea, Qatar, the Netherlands, Korea, India, and Taiwan. The top 15 countries in terms of total amount given are Qatar ($2.71B), England ($1.46B), China ($1.24B), Saudi Arabia ($1.07B), Bermuda ($900M), Canada ($898M), Hong Kong ($887M), Japan ($656M), Switzerland ($620M), India ($540M), Germany ($442M), United Arab Emirates ($431M), France ($406M), Singapore ($401M), and Australia ($248M). Notably, Qatar gives far more per gift on average than any other country — it ranks 11th in number of gifts but 1st in total amount — and Bermuda, Singapore, and the UAE appear in the amount ranking despite not making the top 15 by count, meaning gifts from these countries tend to be especially large.

# %%
#2.6
giftor_summary = (foreign_gifts.groupby("Giftor Name")
    .agg(Number_of_Gifts=("Foreign Gift Amount", "count"),
         Total_Amount=("Foreign Gift Amount", "sum"))
    .sort_values("Total_Amount", ascending=False))

giftor_summary.head(15)
# Out:
#                                      Number_of_Gifts  Total_Amount
# Giftor Name
# Qatar Foundation                                 261    1166503744
# Qatar Foundation/Qatar National Res               10     796197000
# Qatar Foundation for Education                     6     373945215
# Anonymous                                        262     338793629
# Saudi Arabian Cultural Mission                   480     275221475
# HCL                                                5     190000000
# Church of Jesus Christ of LDS                      7     185203715
# Emirates Institute for Advanced Sc                24     170641244
# QIC                                                2     148355497
# Anonymous #9                                       4      96334996
# Qatar National Research Fund                     124      79021705
# Government of Saudi Arabia                        13      75192434
# Contracting Party                                143      69996984
# ...

# %% [markdown]
# **2.6.** Excluding "Anonymous" and "Anonymous #9," which are not identifiable giftors, the entities providing the most money in total are three separately-listed Qatar Foundation variants — "Qatar Foundation" ($1.17B), "Qatar Foundation/Qatar National Res" ($796M), and "Qatar Foundation for Education" ($374M) — likely the same organization recorded inconsistently across records, which together account for over $2.3B. These are followed by Saudi Arabian Cultural Mission ($275M), HCL ($190M), Church of Jesus Christ of LDS ($185M), and Emirates Institute for Advanced Science ($171M).

# %% [markdown]
# ### *Reflection on AI assistance
# In your own words without generative AI.

# %% [markdown]
# AI helped most with polish and completeness rather than correcting substantive errors. The original math and code from Phase 1 were fundamentally sound, so the AI's biggest contributions were: (1) catching that Q1.2 and Q1.3 were structured circularly and rewriting them as proper one-directional proofs; (2) flagging that several Q2 sub-answers existed only implicitly in charts/tables with no written interpretation, even though the questions explicitly asked to "describe" or "notice patterns"; and (3) suggesting a log-scale histogram for 2.2, since the original was unreadable due to outlier gifts stretching the axis to $10^8$.
#
# One limitation is that the AI initially mischaracterized the flat "Real Estate" curve in the Q2.4 KDE plot as evidence that real estate gift amounts were near zero, when it's actually just a density-estimation artifact caused by having only 11 observations - too few to fit a meaningful curve.
#
# I verified the final solution by re-running all revised code myself, confirming each plot and table rendered as expected, and reading every proof and write-up line by line to make sure the logic actually followed rather than just looking polished. My remaining concern is that the "Qatar Foundation" name variants and negative gift amounts are data-quality issues the assignment doesn't ask me to resolve, but they affect how confidently the 2.5/2.6 totals should be interpreted.
